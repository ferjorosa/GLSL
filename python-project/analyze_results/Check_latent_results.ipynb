# %% [markdown]
# # 1 - Discre experiments

# %% [markdown]
# ## 1.1 - Small data

# %%
run = 1
numberOfFolds = 10

data = [
        "hiv_test", 
        "hayes_roth",
        "balance_scale", 
        "car_evaluation",
        "nursery", 
        "breast_cancer", 
        "web_phishing",
        "solar_flare",
        "zoo",
        "vote", 
        "spect_heart",
        "alarm"
       ]

methods = [
           "EAST",
           "BI",
           "MSPN",
           "GLFM", 
           "IL",
           "CIL_1", 
           "CIL_10",
           "GLSL_EMPTY",
           "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/discrete/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    mean_time = stats.mean(learning_time)/1000
            
        except Exception as e: 
            #print(e)
            print("["+methodName+"]: " + fullPath)
    
    print(string_to_show)
# Out:
# hiv_test
#
#
# hayes_roth
#
#
# balance_scale
#
#
# car_evaluation
#
#
# nursery
#
#
# breast_cancer
#
#
# web_phishing
#
#
# solar_flare
#
#
# zoo
#
#
# vote
#
#
# spect_heart
#
#
# alarm

# %% [markdown]
# ## 1.2 - Large data

# %%
run = 1
numberOfFolds = 10

data = [        
        "coil_42", 
        "news_100",
        "webkb_336"
]

methods = [
    "binA",
    "EAST",
    "BI",
    "MSPN",
    "IL",
    "CIL_1",
    "CIL_10",
#     "GLSL_EMPTY",
#     "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/discrete/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    mean_time = stats.mean(learning_time)/1000
            
        except:
            print("["+methodName+"]: " + fullPath)
    
    print(string_to_show)
# Out:
# coil_42
#
#
# news_100
# [EAST]: ../../latent_results/run_1/discrete/news_100/10_folds/EAST/news_100_results_EAST.json
# [IL]: ../../latent_results/run_1/discrete/news_100/10_folds/IL/news_100_results_IL.json
#
#
# webkb_336
# [EAST]: ../../latent_results/run_1/discrete/webkb_336/10_folds/EAST/webkb_336_results_EAST.json
# [IL]: ../../latent_results/run_1/discrete/webkb_336/10_folds/IL/webkb_336_results_IL.json

# %% [markdown]
# # 2 - Continuous experiments

# %% [markdown]
# ## 2.1 - Small data

# %%
run = 1
numberOfFolds = 10

data = [
        "real_state_valuation", 
        "buddymove", 
        "qsar_fish_toxicity", 
        "qsar_aqua_toxicity", 
        "ilpd",
        "alcohol",
        "travel_reviews",
        "wine_quality_white", 
        "wine", 
        "leaf", 
        "nba", 
        "wdbc", 
       ]

methods = [
           "GEAST",
           "KDE",
           "GLFM",
           "MSPN", 
           "IL",
           "CIL_1", 
           "CIL_10",
           "GLSL_EMPTY",
           "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/continuous/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    mean_time = stats.mean(learning_time)/1000
            
        except Exception as e: 
            #print(e)
            print("["+methodName+"]: " + fullPath)
    
    print(string_to_show)
# Out:
# real_state_valuation
#
#
# buddymove
#
#
# qsar_fish_toxicity
#
#
# qsar_aqua_toxicity
#
#
# ilpd
#
#
# alcohol
#
#
# travel_reviews
#
#
# wine_quality_white
#
#
# wine
#
#
# leaf
#
#
# nba
#
#
# wdbc

# %% [markdown]
# ## 2.2 - Large data

# %%
run = 1
numberOfFolds = 10

data = [
        "waveform", 
        "100_plants", 
        "geo_music"
       ]

methods = [
           "KDE",
#            "GEAST", 
           "MSPN", 
           "IL",
           "CIL_1", 
           "CIL_10",
#            "GLSL_EMPTY",
#            "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/continuous/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    mean_time = stats.mean(learning_time)/1000
            
        except Exception as e: 
            #print(e)
            print("["+methodName+"]: " + fullPath)
    
    print(string_to_show)
# Out:
# waveform
#
#
# 100_plants
#
#
# geo_music
# [MSPN]: ../../latent_results/run_1/continuous/geo_music/10_folds/MSPN/geo_music_results_MSPN.json
# [IL]: ../../latent_results/run_1/continuous/geo_music/10_folds/IL/geo_music_results_IL.json

# %% [markdown]
# # 3 - Mixed experiments

# %% [markdown]
# ## 3.1 - Small data

# %%
run = 1
numberOfFolds = 10

data = [
        "haberman", 
        "iris", 
        "user_knowledge",
        "vertebral", 
        "ecoli", 
        "planning_relax", 
        "thoracic_surgery",
        "vehicle", 
        "thyroid",
        "parkinsons", 
        "autos", 
        "ionosphere"
       ]

methods = [
           "KDE",
           "MSPN",
           "GLFM",
           "IL",
           "CIL_1", 
           "CIL_10",
           "GLSL_EMPTY",
           "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/mixed/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    mean_time = stats.mean(learning_time)/1000
            
        except Exception as e: 
            #print(e)
            print("["+methodName+"]: " + fullPath)
    
    print(string_to_show)
# Out:
# haberman
#
#
# iris
#
#
# user_knowledge
#
#
# vertebral
#
#
# ecoli
#
#
# planning_relax
#
#
# thoracic_surgery
#
#
# vehicle
#
#
# thyroid
#
#
# parkinsons
#
#
# autos
#
#
# ionosphere

# %% [markdown]
# ## 3.2 - Large data

# %%
run = 1
numberOfFolds = 10

data = [
        "qsar_biodeg",
        "housing_prices",
        "census_india"
       ]

methods = [
           "KDE",
           "MSPN",
           "GLFM",
#            "IL",
           "CIL_1", 
           "CIL_10",
#            "GLSL_EMPTY",
#            "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/mixed/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    mean_time = stats.mean(learning_time)/1000
            
        except Exception as e: 
            #print(e)
            print("["+methodName+"]: " + fullPath)
    
    print(string_to_show)
# Out:
# qsar_biodeg
#
#
# housing_prices
# [KDE]: ../../latent_results/run_1/mixed/housing_prices/10_folds/KDE/housing_prices_results_KDE.json
#
#
# census_india
# [MSPN]: ../../latent_results/run_1/mixed/census_india/10_folds/MSPN/census_india_results_MSPN.json
