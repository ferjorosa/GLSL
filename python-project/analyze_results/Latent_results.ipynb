# %% [markdown]
# # 1 - Discrete experiments

# %% [markdown]
# ## 1.1 - Small data

# %%
run = 1
numberOfFolds = 10

data = [
        "hiv_test", 
        "hayes_roth",
        "balance_scale", 
        "car_evaluation",
        "nursery", 
        "breast_cancer", 
        "web_phishing",
        "solar_flare",
        "zoo",
        "vote", 
        "spect_heart",
        "alarm"
       ]

methods = [
#         "binA",
#         "LCM",
        "EAST",
        "BI",
        "MSPN",
        "GLFM",
        "IL",
        "CIL_1", 
        "CIL_10",
        "GLSL_EMPTY",
#         "HC",
#         "KDE"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/discrete/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    stdev_ll = stats.stdev(test_ll)
                    mean_time = stats.mean(learning_time)/1000
                    stdev_time = stats.stdev(learning_time)/1000

#                     string_to_show = string_to_show + str("%0.2f" % mean_time) + " & " + "(" + str("%0.2f" % stdev_time)+ ")" + " & "
                    string_to_show = string_to_show + str("%0.2f" % mean_ll) + " & " + "(" + str("%0.2f" % stdev_ll)+ ")" + " & "
            
        except:
            string_to_show = string_to_show + "\multicolumn{2}{c|}{-}" + " & "
            #string_to_show = string_to_show + "$---$" + " & "
    
    print(string_to_show)
# Out:
# hiv_test
# -1485.89 & (4484.39) & -85.61 & (59.44) & -104.84 & (100.70) & -93.68 & (147.46) & -84.22 & (51.96) & -84.48 & (52.02) & -84.22 & (51.96) & -87.63 & (66.47) &
#
# hayes_roth
# -89.72 & (5.91) & -89.98 & (5.68) & -88.89 & (7.87) & -110.67 & (12.99) & -89.09 & (5.71) & -89.09 & (5.71) & -89.09 & (5.71) & -87.16 & (7.67) &
#
# balance_scale
# -492.48 & (16.81) & -491.67 & (16.57) & -483.10 & (45.40) & -505.65 & (34.91) & -487.16 & (15.78) & -487.16 & (15.78) & -487.16 & (15.78) & -560.10 & (49.53) &
#
# car_evaluation
# -12095.26 & (9825.73) & -1610.46 & (251.41) & -1690.90 & (241.26) & -1728.79 & (128.60) & -1503.81 & (185.32) & -1721.09 & (178.65) & -1503.81 & (185.32) & -1693.70 & (82.27) &
#
# nursery
# -264750.76 & (228444.63) & -20307.37 & (2348.33) & -15288.31 & (1017.49) & -14277.25 & (956.67) & -13626.52 & (592.82) & -14153.90 & (1601.28) & -13649.92 & (576.75) & -18286.73 & (961.62) &
#
# breast_cancer
# -321.55 & (91.26) & -258.56 & (24.74) & -310.73 & (39.61) & -415.29 & (66.56) & -261.36 & (24.95) & -262.44 & (25.04) & -261.36 & (24.95) & -259.66 & (23.86) &
#
# web_phishing
# -1018.54 & (19.76) & -1010.19 & (20.93) & -1013.53 & (18.21) & -1758.30 & (126.83) & -1074.22 & (20.75) & -1083.07 & (25.23) & -1074.22 & (20.75) & -992.44 & (22.47) &
#
# solar_flare
# -973.54 & (187.98) & -949.32 & (131.62) & -1106.10 & (131.89) & -1433.10 & (147.16) & -1026.94 & (131.25) & -1033.62 & (131.97) & -1026.94 & (131.25) & -942.32 & (125.25) &
#
# zoo
# -122.54 & (190.95) & -71.86 & (20.60) & -108.94 & (21.31) & -214.64 & (50.84) & -93.05 & (20.94) & -92.31 & (19.95) & -93.05 & (20.94) & -71.98 & (22.11) &
#
# vote
# -216.01 & (79.54) & -176.49 & (21.45) & -174.27 & (19.84) & -440.29 & (99.99) & -193.73 & (24.38) & -194.44 & (25.47) & -193.73 & (24.38) & -177.23 & (21.28) &
#
# spect_heart
# -288.35 & (46.97) & -289.78 & (46.94) & -316.32 & (61.76) & -459.13 & (95.03) & -299.42 & (41.52) & -299.42 & (41.52) & -299.42 & (41.52) & -291.22 & (45.81) &
#
# alarm
# -1179.96 & (536.68) & -1352.71 & (555.29) & -4142.37 & (1027.10) & -5685.95 & (744.38) & -1461.45 & (564.23) & -1430.75 & (499.24) & -1452.13 & (535.00) & -1131.08 & (348.30) &

# %% [markdown]
# ## 1.2 - Large data

# %%
run = 1
numberOfFolds = 10

data = [        
        "coil_42", 
        "news_100",
        "webkb_336"
]

methods = [
#         "binA",
#         "LCM",
        "EAST",
        "BI",
        "MSPN",
        "GLFM",
        "IL",
        "CIL_1", 
        "CIL_10",
        "GLSL_EMPTY",
#         "HC",
#         "KDE"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/discrete/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    stdev_ll = stats.stdev(test_ll)
                    mean_time = stats.mean(learning_time)/1000
                    stdev_time = stats.stdev(learning_time)/1000

                    #string_to_show = string_to_show + str("%0.2f" % mean_time) + " & " + "(" + str("%0.2f" % stdev_time)+ ")" + " & "
                    string_to_show = string_to_show + str("%0.2f" % mean_ll) + " & " + "(" + str("%0.2f" % stdev_ll)+ ")" + " & "
            
        except:
            string_to_show = string_to_show + "\multicolumn{2}{c|}{-}" + " & "
            #string_to_show = string_to_show + "$---$" + " & "
    
    print(string_to_show)
# Out:
# coil_42
# -30597.77 & (45573.34) & -6978.14 & (1501.16) & -6879.65 & (860.33) & -8766.60 & (1107.85) & -6269.05 & (918.52) & -6316.36 & (943.68) & -6269.04 & (918.50) & \multicolumn{2}{c|}{-} &
#
# news_100
# \multicolumn{2}{c|}{-} & -25343.09 & (6113.94) & -26768.92 & (6971.29) & -27434.12 & (7383.22) & \multicolumn{2}{c|}{-} & -26301.65 & (6531.46) & -26325.91 & (6576.45) & \multicolumn{2}{c|}{-} &
#
# webkb_336
# \multicolumn{2}{c|}{-} & -8430.17 & (1681.82) & -9211.57 & (1733.69) & -10721.51 & (2309.92) & \multicolumn{2}{c|}{-} & -9440.12 & (1990.32) & -9439.57 & (1990.87) & \multicolumn{2}{c|}{-} &

# %% [markdown]
# # 2 - Continuous experiments

# %% [markdown]
# ## 2.1 - Small data

# %%
run = 1
numberOfFolds = 10

data = [
        "real_state_valuation", 
        "buddymove", 
        "qsar_fish_toxicity", 
        "qsar_aqua_toxicity", 
        "ilpd",
        "alcohol",
        "travel_reviews",
        "wine_quality_white", 
        "wine", 
        "leaf", 
        "nba", 
        "wdbc", 
       ]

methods = [
           "GEAST",
           "KDE",
           "MSPN",
           "GLFM",
           "IL",
           "CIL_1", 
           "CIL_10",
           "GLSL_EMPTY",
#            "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/continuous/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    stdev_ll = stats.stdev(test_ll)
                    mean_time = stats.mean(learning_time)/1000
                    stdev_time = stats.stdev(learning_time)/1000

                    string_to_show = string_to_show + str("%0.2f" % mean_time) + " & " + "(" + str("%0.2f" % stdev_time)+ ")" + " & "
#                     string_to_show = string_to_show + str("%0.2f" % mean_ll) + " & " + "(" + str("%0.2f" % stdev_ll)+ ")" + " & "
            
        except:
            string_to_show = string_to_show + "\multicolumn{2}{c|}{-}" + " & "
            #string_to_show = string_to_show + "$---$" + " & "
    
    print(string_to_show)
# Out:
# real_state_valuation
# 302.12 & (129.36) & 0.01 & (0.00) & 4.66 & (0.86) & 29.88 & (2.74) & 2.56 & (0.33) & 1.11 & (1.08) & 2.18 & (0.29) & 4922.89 & (4432.58) &
#
# buddymove
# 213.78 & (112.87) & 0.00 & (0.00) & 4.48 & (1.03) & 0.03 & (0.01) & 2.80 & (0.09) & 0.58 & (0.15) & 2.54 & (0.19) & 87.85 & (10.94) &
#
# qsar_fish_toxicity
# 1911.91 & (651.32) & 0.04 & (0.01) & 13.36 & (3.03) & 124.79 & (5.31) & 28.92 & (2.05) & 7.40 & (2.90) & 29.11 & (5.97) & 3169.77 & (3160.07) &
#
# qsar_aqua_toxicity
# 2292.40 & (515.20) & 0.02 & (0.00) & 11.21 & (1.97) & 87.92 & (2.49) & 39.53 & (6.29) & 19.23 & (10.59) & 34.96 & (7.88) & 3116.11 & (1189.20) &
#
# ilpd
# 1757.13 & (490.96) & 0.02 & (0.00) & 15.89 & (2.50) & 0.09 & (0.02) & 43.16 & (2.12) & 2.49 & (0.79) & 29.00 & (3.09) & 33301.14 & (18769.68) &
#
# alcohol
# 316.98 & (68.85) & 0.00 & (0.00) & 5.36 & (1.43) & 11.37 & (0.82) & 6.46 & (1.16) & 1.07 & (0.36) & 3.13 & (0.34) & 646.10 & (63.37) &
#
# travel_reviews
# 4180.70 & (362.00) & 0.08 & (0.02) & 20.19 & (4.47) & 214.64 & (45.86) & 133.72 & (12.18) & 21.57 & (6.18) & 51.54 & (9.17) & 6215.27 & (2923.33) &
#
# wine_quality_white
# 169021.63 & (34671.99) & 1.68 & (0.27) & 91.95 & (9.55) & 1160.05 & (67.81) & 1366.39 & (120.05) & 25.38 & (0.53) & 318.31 & (143.96) & 220342.97 & (107568.86) &
#
# wine
# 795.98 & (145.86) & 0.01 & (0.00) & 13.89 & (2.21) & 29.55 & (1.36) & 21.59 & (1.60) & 0.94 & (0.39) & 4.40 & (0.52) & 3597.89 & (2670.71) &
#
# leaf
# 3941.66 & (420.50) & 0.02 & (0.00) & 9.76 & (0.74) & 85.35 & (12.50) & 61.19 & (4.15) & 0.59 & (0.17) & 12.77 & (2.44) & 1393.00 & (176.48) &
#
# nba
# 13608.33 & (835.63) & 0.03 & (0.00) & 59.87 & (13.16) & 210.85 & (0.79) & 257.69 & (9.89) & 5.61 & (2.50) & 49.60 & (12.67) & 49550.76 & (30447.24) &
#
# wdbc
# 50784.86 & (3315.22) & 0.08 & (0.02) & 52.60 & (1.43) & 776.45 & (10.12) & 2436.78 & (26.62) & 8.90 & (1.61) & 57.90 & (4.24) & 152898.31 & (36975.97) &

# %% [markdown]
# ## 2.2 - Large data

# %%
run = 1
numberOfFolds = 10

data = [
        "waveform", 
        "100_plants", 
        "geo_music"
       ]

methods = [
           "GEAST",
           "KDE",
           "MSPN",
           "GLFM",
           "IL",
           "CIL_1", 
           "CIL_10",
           "GLSL_EMPTY",
#            "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/continuous/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    stdev_ll = stats.stdev(test_ll)
                    mean_time = stats.mean(learning_time)/1000
                    stdev_time = stats.stdev(learning_time)/1000

                    #string_to_show = string_to_show + str("%0.2f" % mean_time) + " & " + "(" + str("%0.2f" % stdev_time)+ ")" + " & "
                    string_to_show = string_to_show + str("%0.2f" % mean_ll) + " & " + "(" + str("%0.2f" % stdev_ll)+ ")" + " & "
            
        except:
            string_to_show = string_to_show + "\multicolumn{2}{c|}{-}" + " & "
            #string_to_show = string_to_show + "$---$" + " & "
    
    print(string_to_show)
# Out:
# waveform
# \multicolumn{2}{c|}{-} & -32643.86 & (56.89) & -30816.14 & (207.60) & -40771.48 & (563.01) & -30370.28 & (59.91) & -31238.63 & (280.32) & -30580.09 & (152.53) & \multicolumn{2}{c|}{-} &
#
# 100_plants
# \multicolumn{2}{c|}{-} & 31175.92 & (777.24) & -13220.36 & (13736.14) & -15808.74 & (7583.75) & 28239.13 & (2198.29) & 28193.23 & (2202.93) & 28197.25 & (2206.23) & \multicolumn{2}{c|}{-} &
#
# geo_music
# \multicolumn{2}{c|}{-} & -10029.05 & (294.76) & \multicolumn{2}{c|}{-} & -29926.40 & (1059.27) & \multicolumn{2}{c|}{-} & -10749.96 & (374.64) & -9287.31 & (365.14) & \multicolumn{2}{c|}{-} &

# %% [markdown]
# # 3 - Mixed experiments

# %% [markdown]
# ## 3.1 - Small data

# %%
run = 1
numberOfFolds = 10

data = [
        "haberman", 
        "iris", 
        "user_knowledge",
        "vertebral", 
        "ecoli", 
        "planning_relax", 
        "thoracic_surgery",
        "vehicle", 
        "thyroid",
        "parkinsons", 
        "autos", 
        "ionosphere"
       ]

methods = [
           "KDE",
           "MSPN",
           "GLFM",
           "IL",
           "CIL_1", 
           "CIL_10",
           "GLSL_EMPTY",
#             "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/mixed/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    stdev_ll = stats.stdev(test_ll)
                    mean_time = stats.mean(learning_time)/1000
                    stdev_time = stats.stdev(learning_time)/1000

#                     string_to_show = string_to_show + str("%0.2f" % mean_time) + " & " + "(" + str("%0.2f" % stdev_time)+ ")" + " & "
                    string_to_show = string_to_show + str("%0.2f" % mean_ll) + " & " + "(" + str("%0.2f" % stdev_ll)+ ")" + " & "
            
        except:
            string_to_show = string_to_show + "\multicolumn{2}{c|}{-}" + " & "
            #string_to_show = string_to_show + "$---$" + " & "
    
    print(string_to_show)
# Out:
# haberman
# -319.16 & (38.41) & -1012.93 & (379.19) & -376.13 & (44.48) & -278.13 & (35.51) & -325.79 & (43.90) & -278.13 & (35.51) & -299.88 & (38.67) &
#
# iris
# -69.51 & (6.97) & -194.20 & (124.36) & -406.22 & (339.04) & -51.10 & (12.05) & -46.31 & (11.63) & -51.11 & (12.05) & -33.60 & (13.85) &
#
# user_knowledge
# -29.03 & (20.15) & -194.36 & (188.05) & -292.22 & (125.60) & -20.15 & (22.66) & -20.15 & (22.66) & -20.15 & (22.66) & -1.71 & (18.00) &
#
# vertebral
# -798.78 & (72.53) & -610.13 & (237.69) & -1192.51 & (444.36) & -763.81 & (68.16) & -779.00 & (61.80) & -763.84 & (68.14) & -606.32 & (82.31) &
#
# ecoli
# 1584.42 & (245.21) & -180.73 & (190.28) & -592.32 & (1205.38) & 12.26 & (125.52) & -4.43 & (113.00) & 12.24 & (125.59) & 169.63 & (70.39) &
#
# planning_relax
# -94.31 & (14.73) & -1087.97 & (307.52) & -617.46 & (194.49) & -44.72 & (22.26) & -44.72 & (22.26) & -44.72 & (22.26) & 28.54 & (28.49) &
#
# thoracic_surgery
# -750.57 & (5.73) & -671.51 & (52.22) & -1726.67 & (702.16) & -553.39 & (14.57) & -566.58 & (17.40) & -566.58 & (17.40) & -513.54 & (18.00) &
#
# vehicle
# -5469.10 & (122.74) & -8801.35 & (3295.42) & -20567.24 & (1500.78) & -5245.73 & (135.66) & -5662.02 & (107.25) & -5309.80 & (150.54) & -4682.75 & (91.48) &
#
# thyroid
# -7151.07 & (97.26) & -5943.21 & (119.81) & -20475.09 & (2517.29) & -6047.79 & (192.81) & -6864.09 & (294.07) & -6680.76 & (301.05) & -5786.55 & (89.43) &
#
# parkinsons
# 562.01 & (66.83) & -981.89 & (933.66) & -946.90 & (1218.76) & 458.41 & (186.02) & 407.76 & (193.57) & 429.48 & (184.91) & 525.70 & (171.17) &
#
# autos
# nan & (nan) & -2136.42 & (386.91) & -2528.45 & (391.36) & -1478.48 & (582.03) & -1369.79 & (109.24) & -1308.21 & (111.15) & -1211.35 & (470.75) &
#
# ionosphere
# -682.32 & (202.73) & -6633.65 & (3123.35) & -5846.25 & (1474.37) & -722.87 & (284.33) & -811.49 & (247.98) & -731.52 & (279.00) & -92.51 & (410.13) &

# %% [markdown]
# ## 3.2 - Large data

# %%
run = 1
numberOfFolds = 10

data = [
        "qsar_biodeg",
        "housing_prices",
        "census_india"
       ]

methods = [
           "KDE",
           "MSPN", 
           "GLFM",
           "IL",
           "CIL_1", 
           "CIL_10",
           "GLSL_EMPTY",
#            "HC"
          ]

base_directory_path = "../../latent_results/run_" + str(run) + "/mixed/" 

import json
import statistics as stats
    
for dataName in data:
    
    print("\n" + dataName)
    string_to_show = ""
    
    for methodName in methods:
        directoryName = dataName + "/" + str(numberOfFolds) + "_folds/" + methodName + "/"
        jsonName = dataName + "_results_" + methodName + ".json"
        fullPath = base_directory_path + directoryName + jsonName
        test_ll = []
        learning_time = []
        
        try:
            with open(fullPath) as json_file:
                    jsonData = json.load(json_file)
                    foldsData = jsonData["folds"]
                    for i in range(1,11):
                        test_ll.append(foldsData["fold_"+str(i)]["test_LL"])
                        learning_time.append(foldsData["fold_"+str(i)]["learning_time"])

                    mean_ll = stats.mean(test_ll)
                    stdev_ll = stats.stdev(test_ll)
                    mean_time = stats.mean(learning_time)/1000
                    stdev_time = stats.stdev(learning_time)/1000

                    string_to_show = string_to_show + str("%0.2f" % mean_time) + " & " + "(" + str("%0.2f" % stdev_time)+ ")" + " & "
                    #string_to_show = string_to_show + str("%0.2f" % mean_ll) + " & " + "(" + str("%0.2f" % stdev_ll)+ ")" + " & "
        
        except:
            string_to_show = string_to_show + "\multicolumn{2}{c|}{-}" + " & "
            #string_to_show = string_to_show + "$---$" + " & "
    
    print(string_to_show)
# Out:
# qsar_biodeg
# 0.17 & (0.00) & 491.29 & (37.76) & 3500.91 & (118.78) & 25229.09 & (1098.92) & 26.23 & (8.98) & 1108.75 & (282.47) & \multicolumn{2}{c|}{-} &
#
# housing_prices
# \multicolumn{2}{c|}{-} & 750.93 & (99.15) & 10106.29 & (1525.88) & \multicolumn{2}{c|}{-} & 94.33 & (32.56) & 1149.53 & (706.70) & \multicolumn{2}{c|}{-} &
#
# census_india
# 1.47 & (0.04) & \multicolumn{2}{c|}{-} & 43458.55 & (2819.02) & \multicolumn{2}{c|}{-} & 2948.52 & (1838.42) & 23575.06 & (4266.94) & \multicolumn{2}{c|}{-} &
