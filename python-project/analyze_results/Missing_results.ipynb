# %% [markdown]
# # 1 - Discrete

# %% [markdown]
# ## 1.1 - Average error diagram

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np

methods = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE", 
    "VBSEM", 
    #"glsl_EMPTY"
          ]
max_percentage = 6
n_runs = 5
directories = ["../../missing_results/discrete/"]
accuracy_error_dfs = []
data_names = [
        "hiv_test", 
        "hayes_roth",
        "balance_scale", 
        "car_evaluation",
        "nursery", 
        "breast_cancer", 
        "web_phishing",
        "solar_flare",
        "zoo",
        "vote", 
        "spect_heart",
        "alarm"
]
average_error_dfs = []
average_time_dfs = []

# Iterate through the missing percentage values, and for each dataset, recover the methods' results
for i in range(1, max_percentage):
    miss_percentage_string = "0" + str(i)

    df_error_results = pd.DataFrame(columns=methods)
    df_time_results = pd.DataFrame(columns=methods)

    for directory in directories:       

        for data_name in data_names:
                       
            error_results = {"dataset": data_name}
            time_results = {"dataset": data_name}
            
            for method_name in methods:
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                with open(full_path) as json_file:
                    json_data = json.load(json_file)
                    runs_data = json_data["runs"]
                    errors = []
                    learning_times = []
                    for j in range(1, n_runs + 1):  
                        
                        learning_times.append(runs_data["run_" + str(j)]["learning_time"]/1000)

                        if directory == "../../missing_results/discrete/":
                            errors.append(1.0 - runs_data["run_" + str(j)]["accuracy"])
                        elif directory == "../../missing_results/continuous/":
                            errors.append(runs_data["run_" + str(j)]["nrmse"])
                        else:
                            errors.append(runs_data["run_" + str(j)]["average_error"])

                    avg_learning_time = stats.mean(learning_times)
                    avg_error = stats.mean(errors)
                    #stdev_error = stats.stdev(errors)

                    error_results[method_name] = avg_error
                    time_results[method_name] = avg_learning_time

            df_error_results = df_error_results.append(error_results, ignore_index=True)
            df_time_results = df_time_results.append(time_results, ignore_index=True)

    average_error_dfs.append(df_error_results)
    average_time_dfs.append(df_time_results)
    
# Rename GLSL columns
for i in range(0, max_percentage-1):
    average_error_dfs[i] = average_error_dfs[i].rename(columns={"VBSEM": "GLSL", "HIVAE": "HI-VAE"})
    average_time_dfs[i] = average_time_dfs[i].rename(columns={"VBSEM": "GLSL", "HIVAE": "HI-VAE"})
    
renamed_methods = ["MEAN", "MICE", "GLFM", "HI-VAE", "GLSL"]

# %%
df_error_plot = pd.DataFrame(columns=["dataset", "method", "percentage", "AvgErr"])

for percentage in range(0, 5):
    df = average_error_dfs[percentage]
    percentage_string = str((percentage+1)*10) + "%"
    for method in renamed_methods:
        for i in range(len(df)):
            row = df.loc[i]
            instance = {"dataset": row["dataset"]}
            instance["percentage"] = percentage_string
            instance["method"] = method
            instance["AvgErr"] = row[method]
            df_error_plot = df_error_plot.append(instance, ignore_index=True)

######################################
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(16,10))
g = sns.boxplot(data=df_error_plot,x="percentage", y="AvgErr", hue="method", ax = ax)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.10),
          ncol=6, fancybox=True, shadow=True)
plt.setp(ax.get_legend().get_texts(), fontsize='25') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='0') # for legend title
ax.tick_params(axis="x", labelsize=20) # x ticks font size
ax.tick_params(axis="y", labelsize=20) # y ticks font size
plt.xlabel('Percentage', fontsize=30, labelpad=30)
plt.ylabel('Average error', fontsize=30, labelpad=30)

plt.savefig('discrete_average_errors.pdf')

# %% [markdown]
# ## 1.2 - All error diagrams

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np

methods_1 = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE", 
    "VBSEM", 
]

methods_2 = [
    "MEAN", 
    "MICE", 
    "GLFM", 
#     "HIVAE",
#     "VBSEM", 
]

renamed_methods_1 = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HI-VAE", 
    "GLSL"
]
    
renamed_methods_2 = [
    "MEAN", 
    "MICE", 
    "GLFM", 
#         "HI-VAE", 
#         "GLSL"
]

max_percentage = 6
n_runs = 5
directory = "../../missing_results/discrete/"
data_names = [
        "hiv_test", 
        "hayes_roth",
        "balance_scale", 
        "car_evaluation",
        "nursery", 
        "breast_cancer", 
        "web_phishing",
        "solar_flare",
        "zoo",
        "vote", 
        "spect_heart",
        "alarm",
        "coil_42",
        "news_100",
        "webkb_336"
]

data_names_fancy = ["HIV test", "Hayes roth", "Balance scale", "Car evaluaiton", "Nursery", "Breast cancer", 
                    "Web Phishing", "Solar flare", "Zoo", "Vote", "Spect heart", "Alarm", "Coil 42", "News 100", "WebKb 336"]



row_count = 0 # Counts for plotting (row axis)
col_count = 0 # Counts for plotting (col axis)

from matplotlib import pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(5, 3, figsize=(20,20))

for d in range(0, len(data_names)):
    data_name=data_names[d]
    
    error_dfs = [] # One for each percentage
    
    if d < 12:
        methods = methods_1
        renamed_methods = renamed_methods_1
    else:
        methods = methods_2
        renamed_methods = renamed_methods_2
    
    for p in range(1, max_percentage):
        miss_percentage_string = "0" + str(p)
        df_error_results = pd.DataFrame(columns=methods)
        
        for i in range(1, n_runs + 1):

            error_results = {"run": i}
        
                
            for method_name in methods:
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                with open(full_path) as json_file:
                    json_data = json.load(json_file)
                    runs_data = json_data["runs"]
                    errors = []
                    learning_times = []

                    if directory == "../../missing_results/discrete/":
                        error_results[method_name] = 1.0 - runs_data["run_" + str(i)]["accuracy"]
                    elif directory == "../../missing_results/continuous/":
                        error_results[method_name] = runs_data["run_" + str(i)]["nrmse"]
                    else:
                        error_results[method_name] = runs_data["run_" + str(i)]["average_error"]

            df_error_results = df_error_results.append(error_results, ignore_index=True)

        error_dfs.append(df_error_results)
    
    # Rename columns
    for i in range(0, max_percentage-1):
        error_dfs[i] = error_dfs[i].rename(columns={"VBSEM": "GLSL", "HIVAE": "HI-VAE"})
    
    ############################################################################
    # Prepare DF for plotting
    ############################################################################
    df_plot = pd.DataFrame(columns=["dataset", "method", "percentage", "AvgErr"])

    for percentage in range(0, 5):
        df = error_dfs[percentage]
        percentage_string = str((percentage+1)*10) + "%"
        for method in renamed_methods:
            for i in range(len(df)):
                row = df.loc[i]
                instance = {"run": row["run"]}
                instance["percentage"] = percentage_string
                instance["method"] = method
                instance["AvgErr"] = row[method]
                df_plot = df_plot.append(instance, ignore_index=True)
                
    ############################################################################
    # Plotting
    ############################################################################
#     print(str(row_count) + "," + str(col_count))
    g = sns.lineplot(data=df_plot,x="percentage", y="AvgErr", hue="method", err_style="bars", ax = axs[row_count, col_count], legend=False)
    axs[row_count, col_count].set_title(data_names_fancy[d], fontsize=18)
    axs[row_count, col_count].set_ylabel("Average error", fontsize=15, labelpad=10)
    axs[row_count, col_count].set_xlabel("Percentage", fontsize=15, labelpad=10)
    axs[row_count, col_count].tick_params(axis="x", labelsize=12) # x ticks font size
    axs[row_count, col_count].tick_params(axis="y", labelsize=12) # x ticks font size
       
    #### Update row/column index of the axis plot
    col_count = col_count + 1
    if col_count == 3:
        col_count = 0
        row_count = row_count + 1
    
#############################################################################
# Final adjustments to the plot
############################################################################
axs[0,1].legend(loc='upper center', bbox_to_anchor=(0.5, 1.50),  fancybox=True, shadow=True, ncol=5, labels=['MEAN', 'MICE', 'GLFM', 'HI-VAE', 'GLSL'])
plt.setp(axs[0,1].get_legend().get_texts(), fontsize='25') # for legend text
plt.setp(axs[0,1].get_legend().get_title(), fontsize='0') # for legend title
for line in axs[0,1].get_legend().get_lines():
    line.set_linewidth(4.0)

fig.subplots_adjust(hspace=0.5)
fig.subplots_adjust(wspace=0.3)

plt.savefig('discrete_errors.pdf')

# %% [markdown]
# ## 1.3 - Execution times

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np
from math import nan

methods = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE",  
    "glsl_EMPTY"
          ]
max_percentage = 6
n_runs = 5
directories = ["../../missing_results/discrete/"]
accuracy_error_dfs = []
data_names = [
        "hiv_test", 
        "hayes_roth",
        "balance_scale", 
        "car_evaluation",
        "nursery", 
        "breast_cancer", 
        "web_phishing",
        "solar_flare",
        "zoo",
        "vote", 
        "spect_heart",
        "alarm",
        "coil_42",
        "news_100",
        "webkb_336"
]

df_avg_time_results = pd.DataFrame(columns=methods)
df_stdev_time_results = pd.DataFrame(columns=methods)

for directory in directories:       
    for data_name in data_names:
        # Creamos 2 diccionarios con los valores medios y sd de cada metodo
        avg_time_results = {"dataset": data_name}
        stdev_time_results = {"dataset": data_name}       
        for method_name in methods:
            learning_times = []
        
            for i in range(1, max_percentage):
                miss_percentage_string = "0" + str(i)
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                try:
                    with open(full_path) as json_file:
                        json_data = json.load(json_file)
                        runs_data = json_data["runs"]
                        for j in range(1, n_runs + 1):  
                            learning_times.append(runs_data["run_" + str(j)]["learning_time"]/1000)
                except:
                    learning_times.append(nan)
            avg_learning_time = stats.mean(learning_times)
            avg_time_results[method_name] = avg_learning_time
            stdev_learning_time = stats.stdev(learning_times)
            stdev_time_results[method_name] = stdev_learning_time
        
        df_avg_time_results = df_avg_time_results.append(avg_time_results, ignore_index=True)
        df_stdev_time_results = df_stdev_time_results.append(stdev_time_results, ignore_index=True)
        
df_avg_time_results
# df_stdev_time_results
# Out:
#        MEAN        MICE          GLFM        HIVAE    glsl_EMPTY  \
# 0   0.00032    0.042811      9.616988    30.041689  5.409896e+01
# 1   0.00008    0.047791      6.375878    34.148891  3.326144e+01
# 2   0.00184    0.048137     27.495184    38.490118  1.364637e+02
# 3   0.00276    0.092765    122.236998    61.362876  1.622916e+03
# 4   0.01368    0.474472   1373.714173   725.404255  7.155875e+04
# 5   0.00076    0.096824     29.832636    53.479853  3.231105e+03
# 6   0.00156    0.148432    185.683463    84.748482  7.901435e+03
# 7   0.00192    0.255186    128.024027   100.479860  7.591943e+04
# 8   0.00024    0.207980     22.706113    99.180352  8.691764e+03
# 9   0.00048    0.197075     35.994790   105.451609  7.361499e+03
# 10  0.00064    0.318630     45.561592   102.377813  1.302211e+04
# 11  0.00384    2.583101    340.326631   296.012895  1.200849e+06
# 12  0.02676   11.814529   1596.185117  1046.578502           NaN
# 13  0.20836  187.621452  13637.222659  9927.243557           NaN
# 14  0.03588  819.955367   4422.085772  3233.387141           NaN
#
#            dataset
# 0         hiv_test
# 1       hayes_roth
# 2    balance_scale
# 3   car_evaluation
# 4          nursery
# 5    breast_cancer
# 6     web_phishing
# 7      solar_flare
# 8              zoo
# 9             vote
# 10     spect_heart
# 11           alarm
# 12         coil_42
# 13        news_100
# 14       webkb_336

# %% [markdown]
# # 2 - Continuous

# %% [markdown]
# ## 2.1 - Average error diagram

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np

methods = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE", 
    "VBSEM", 
    #"glsl_EMPTY"
          ]
max_percentage = 6
n_runs = 5
directories = ["../../missing_results/continuous/"]
accuracy_error_dfs = []
data_names = [
        "real_state_valuation", 
        "buddymove", 
        "qsar_fish_toxicity", 
        "qsar_aqua_toxicity", 
        "ilpd",
        "alcohol",
        "travel_reviews",
        "wine_quality_white", 
        "wine", 
        "leaf", 
        "nba", 
        "wdbc"
]
average_error_dfs = []
average_time_dfs = []

# Iterate through the missing percentage values, and for each dataset, recover the methods' results
for i in range(1, max_percentage):
    miss_percentage_string = "0" + str(i)

    df_error_results = pd.DataFrame(columns=methods)
    df_time_results = pd.DataFrame(columns=methods)

    for directory in directories:       

        for data_name in data_names:
            
            error_results = {"dataset": data_name}
            time_results = {"dataset": data_name}
            
            for method_name in methods:
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                with open(full_path) as json_file:
                    json_data = json.load(json_file)
                    runs_data = json_data["runs"]
                    errors = []
                    learning_times = []
                    for j in range(1, n_runs + 1):  
                        
                        learning_times.append(runs_data["run_" + str(j)]["learning_time"]/1000)

                        if directory == "../../missing_results/discrete/":
                            errors.append(1.0 - runs_data["run_" + str(j)]["accuracy"])
                        elif directory == "../../missing_results/continuous/":
                            errors.append(runs_data["run_" + str(j)]["nrmse"])
                        else:
                            errors.append(runs_data["run_" + str(j)]["average_error"])

                    avg_learning_time = stats.mean(learning_times)
                    avg_error = stats.mean(errors)
                    #stdev_error = stats.stdev(errors)

                    error_results[method_name] = avg_error
                    time_results[method_name] = avg_learning_time

            df_error_results = df_error_results.append(error_results, ignore_index=True)
            df_time_results = df_time_results.append(time_results, ignore_index=True)

    average_error_dfs.append(df_error_results)
    average_time_dfs.append(df_time_results)
    
# Rename GLSL columns
for i in range(0, max_percentage-1):
    average_error_dfs[i] = average_error_dfs[i].rename(columns={"VBSEM": "GLSL", "HIVAE": "HI-VAE"})
    average_time_dfs[i] = average_time_dfs[i].rename(columns={"VBSEM": "GLSL", "HIVAE": "HI-VAE"})
    
renamed_methods = ["MEAN", "MICE", "GLFM", "HI-VAE", "GLSL"]

# %%
df_error_plot = pd.DataFrame(columns=["dataset", "method", "percentage", "AvgErr"])

for percentage in range(0, 5):
    df = average_error_dfs[percentage]
    percentage_string = str((percentage+1)*10) + "%"
    for method in renamed_methods:
        for i in range(len(df)):
            row = df.loc[i]
            instance = {"dataset": row["dataset"]}
            instance["percentage"] = percentage_string
            instance["method"] = method
            instance["AvgErr"] = row[method]
            df_error_plot = df_error_plot.append(instance, ignore_index=True)

######################################
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(16,10))
g = sns.boxplot(data=df_error_plot,x="percentage", y="AvgErr", hue="method", ax = ax)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.10),
          ncol=6, fancybox=True, shadow=True)
plt.setp(ax.get_legend().get_texts(), fontsize='25') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='0') # for legend title
ax.tick_params(axis="x", labelsize=20) # x ticks font size
ax.tick_params(axis="y", labelsize=20) # y ticks font size
plt.xlabel('Percentage', fontsize=30, labelpad=30)
plt.ylabel('Average error', fontsize=30, labelpad=30)

plt.savefig('continuous_average_errors.pdf')

# %% [markdown]
# ## 2.2 - All error diagrams

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np

methods_1 = ["MEAN", "MICE", "GLFM", "HIVAE", "VBSEM"]

methods_2 = [ "MEAN", "MICE", "GLFM", "HIVAE"]

methods_3 = [ "MEAN", "MICE", "GLFM"]

renamed_methods_1 = ["MEAN", "MICE", "GLFM", "HI-VAE", "VBSEM"]
    
renamed_methods_2 = ["MEAN", "MICE", "GLFM",  "HI-VAE"]

renamed_methods_3 = [ "MEAN", "MICE", "GLFM"]

max_percentage = 6
n_runs = 5
directory ="../../missing_results/continuous/"
data_names = [
        "real_state_valuation", 
        "buddymove", 
        "qsar_fish_toxicity", 
        "qsar_aqua_toxicity", 
        "ilpd",
        "alcohol",
        "travel_reviews",
        "wine_quality_white", 
        "wine", 
        "leaf", 
        "nba", 
        "wdbc",
        "waveform", 
        "100_plants", 
        "geo_music"
]

data_names_fancy = ["Real state valuation", "Buddymove", "Qsar-fish", "Qsar-aqua", "ILPD", "Alcohol", "Travel reviews",
                   "Wine-quality", "Wine", "Leaf", "NBA", "WDBC", "Waveform", "100-plants", "Geo-music"]



row_count = 0 # Counts for plotting (row axis)
col_count = 0 # Counts for plotting (col axis)

from matplotlib import pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(5, 3, figsize=(20,25))

for d in range(0, len(data_names)):
    data_name=data_names[d]
    
    error_dfs = [] # One for each percentage
    
    if d < 12:
        methods = methods_1
        renamed_methods = renamed_methods_1
        
    elif d == 14:
        methods = methods_3
        renamed_methods = renamed_methods_3
    else:
        methods = methods_2
        renamed_methods = renamed_methods_2
    
    for p in range(1, max_percentage):
        miss_percentage_string = "0" + str(p)
        df_error_results = pd.DataFrame(columns=methods)
        
        for i in range(1, n_runs + 1):

            error_results = {"run": i}
        
            for method_name in methods:
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                with open(full_path) as json_file:
                    json_data = json.load(json_file)
                    runs_data = json_data["runs"]
                    errors = []
                    learning_times = []

                    if directory == "../../missing_results/discrete/":
                        error_results[method_name] = 1.0 - runs_data["run_" + str(i)]["accuracy"]
                    elif directory == "../../missing_results/continuous/":
                        error_results[method_name] = runs_data["run_" + str(i)]["nrmse"]
                    else:
                        error_results[method_name] = runs_data["run_" + str(i)]["average_error"]

            df_error_results = df_error_results.append(error_results, ignore_index=True)

        error_dfs.append(df_error_results)
    
    # Rename columns
    for i in range(0, max_percentage-1):
        error_dfs[i] = error_dfs[i].rename(columns={"HIVAE": "HI-VAE"})
    
    ############################################################################
    # Prepare DF for plotting
    ############################################################################
    df_plot = pd.DataFrame(columns=["dataset", "method", "percentage", "AvgErr"])

    for percentage in range(0, 5):
        df = error_dfs[percentage]
        percentage_string = str((percentage+1)*10) + "%"
        for method in renamed_methods:
            for i in range(len(df)):
                row = df.loc[i]
                instance = {"run": row["run"]}
                instance["percentage"] = percentage_string
                instance["method"] = method
                instance["AvgErr"] = row[method]
                df_plot = df_plot.append(instance, ignore_index=True)
                
    ############################################################################
    # Plotting
    ############################################################################
    g = sns.lineplot(data=df_plot,x="percentage", y="AvgErr", hue="method", err_style="bars", ax = axs[row_count, col_count], legend=False)
    axs[row_count, col_count].set_title(data_names_fancy[d], fontsize=18)
    axs[row_count, col_count].set_ylabel("Average error", fontsize=15, labelpad=10)
    axs[row_count, col_count].set_xlabel("Percentage", fontsize=15, labelpad=10)
    axs[row_count, col_count].tick_params(axis="x", labelsize=12) # x ticks font size
    axs[row_count, col_count].tick_params(axis="y", labelsize=12) # x ticks font size
       
    #### Update row/column index of the axis plot
    col_count = col_count + 1
    if col_count == 3:
        col_count = 0
        row_count = row_count + 1
    
    #############################################################################
    # Final adjustments to the plot

axs[0,1].legend(loc='upper center', bbox_to_anchor=(0.5, 1.50),  fancybox=True, shadow=True, ncol=5, labels=['MEAN', 'MICE', 'GLFM', 'HI-VAE', 'GLSL'])
plt.setp(axs[0,1].get_legend().get_texts(), fontsize='25') # for legend text
plt.setp(axs[0,1].get_legend().get_title(), fontsize='0') # for legend title
for line in axs[0,1].get_legend().get_lines():
    line.set_linewidth(4.0)

fig.subplots_adjust(hspace=0.6)
fig.subplots_adjust(wspace=0.3)

plt.savefig('continuous_errors.pdf')

# %% [markdown]
# ## 2.3 - Execution times

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np
from math import nan

methods = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE",  
    "glsl_EMPTY"
          ]
max_percentage = 6
n_runs = 5
directories = ["../../missing_results/continuous/"]
accuracy_error_dfs = []
data_names = [
        "real_state_valuation", 
        "buddymove", 
        "qsar_fish_toxicity", 
        "qsar_aqua_toxicity", 
        "ilpd",
        "alcohol",
        "travel_reviews",
        "wine_quality_white", 
        "wine", 
        "leaf", 
        "nba", 
        "wdbc",
        "waveform", 
        "100_plants", 
        "geo_music"
]

df_avg_time_results = pd.DataFrame(columns=methods)
df_stdev_time_results = pd.DataFrame(columns=methods)

for directory in directories:       
    for data_name in data_names:
        # Creamos 2 diccionarios con los valores medios y sd de cada metodo
        avg_time_results = {"dataset": data_name}
        stdev_time_results = {"dataset": data_name}       
        for method_name in methods:
            learning_times = []
        
            for i in range(1, max_percentage):
                miss_percentage_string = "0" + str(i)
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                try:
                    with open(full_path) as json_file:
                        json_data = json.load(json_file)
                        runs_data = json_data["runs"]
                        for j in range(1, n_runs + 1):  
                            learning_times.append(runs_data["run_" + str(j)]["learning_time"]/1000)
                except:
                    learning_times.append(nan)
            avg_learning_time = stats.mean(learning_times)
            avg_time_results[method_name] = avg_learning_time
            stdev_learning_time = stats.stdev(learning_times)
            stdev_time_results[method_name] = stdev_learning_time
        
        df_avg_time_results = df_avg_time_results.append(avg_time_results, ignore_index=True)
        df_stdev_time_results = df_stdev_time_results.append(stdev_time_results, ignore_index=True)
        
df_avg_time_results
# df_stdev_time_results
# Out:
#        MEAN       MICE         GLFM        HIVAE    glsl_EMPTY  \
# 0   0.00040   0.044221    15.571654    59.554231    1651.04740
# 1   0.00072   0.068257    14.140395    69.398144     518.41612
# 2   0.00084   0.088249    73.211309    90.794089    3245.26072
# 3   0.00100   0.102924    70.448298   103.168277    6483.70224
# 4   0.00268   0.138749    99.030820   184.029686   11009.09324
# 5   0.00736   0.113750    16.466790   186.324675    1064.19984
# 6   0.00100   0.145347   156.853228   115.992997   14084.96040
# 7   0.00556   0.541267  1158.774478   369.924772  722189.03684
# 8   0.00144   0.156250    44.860019   144.380717    4867.44880
# 9   0.00112   0.182524   100.784128   144.202546    8211.78756
# 10  0.00272   0.233740   343.200008   259.487555   81962.45264
# 11  0.00456   0.608783  1053.379493   295.099767  359282.92468
# 12  0.01608   8.669398  1922.377379  1361.516626           NaN
# 13  0.00708   2.019825  8902.592827  1073.488957           NaN
# 14  0.00888  14.928890  5967.753227          NaN           NaN
#
#                  dataset
# 0   real_state_valuation
# 1              buddymove
# 2     qsar_fish_toxicity
# 3     qsar_aqua_toxicity
# 4                   ilpd
# 5                alcohol
# 6         travel_reviews
# 7     wine_quality_white
# 8                   wine
# 9                   leaf
# 10                   nba
# 11                  wdbc
# 12              waveform
# 13            100_plants
# 14             geo_music

# %% [markdown]
# # 3 - Mixed

# %% [markdown]
# ## 3.1 - Average error plot

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np

methods = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE", 
    "VBSEM", 
    #"glsl_EMPTY"
          ]
max_percentage = 6
n_runs = 5
directories = ["../../missing_results/mixed/"]
accuracy_error_dfs = []
data_names = [
        "haberman", 
        "iris", 
        "user_knowledge",
        "vertebral", 
        "ecoli", 
        "planning_relax", 
        "thoracic_surgery",
        "vehicle", 
        "thyroid",
        "parkinsons", 
        "autos", 
        "ionosphere"
]
average_error_dfs = []
average_time_dfs = []

# Iterate through the missing percentage values, and for each dataset, recover the methods' results
for i in range(1, max_percentage):
    miss_percentage_string = "0" + str(i)

    df_error_results = pd.DataFrame(columns=methods)
    df_time_results = pd.DataFrame(columns=methods)

    for directory in directories:       

        for data_name in data_names:
            
            error_results = {"dataset": data_name}
            time_results = {"dataset": data_name}
            
            for method_name in methods:
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                with open(full_path) as json_file:
                    json_data = json.load(json_file)
                    runs_data = json_data["runs"]
                    errors = []
                    learning_times = []
                    for j in range(1, n_runs + 1):  
                        
                        learning_times.append(runs_data["run_" + str(j)]["learning_time"]/1000)

                        if directory == "../../missing_results/discrete/":
                            errors.append(1.0 - runs_data["run_" + str(j)]["accuracy"])
                        elif directory == "../../missing_results/continuous/":
                            errors.append(runs_data["run_" + str(j)]["nrmse"])
                        else:
                            errors.append(runs_data["run_" + str(j)]["average_error"])

                    avg_learning_time = stats.mean(learning_times)
                    avg_error = stats.mean(errors)
                    #stdev_error = stats.stdev(errors)

                    error_results[method_name] = avg_error
                    time_results[method_name] = avg_learning_time

            df_error_results = df_error_results.append(error_results, ignore_index=True)
            df_time_results = df_time_results.append(time_results, ignore_index=True)

    average_error_dfs.append(df_error_results)
    average_time_dfs.append(df_time_results)
    
# Rename GLSL columns
for i in range(0, max_percentage-1):
    average_error_dfs[i] = average_error_dfs[i].rename(columns={"VBSEM": "GLSL", "HIVAE": "HI-VAE"})
    average_time_dfs[i] = average_time_dfs[i].rename(columns={"VBSEM": "GLSL", "HIVAE": "HI-VAE"})
    
renamed_methods = ["MEAN", "MICE", "GLFM", "HI-VAE", "GLSL"]

# %%
df_error_plot = pd.DataFrame(columns=["dataset", "method", "percentage", "AvgErr"])

for percentage in range(0, 5):
    df = average_error_dfs[percentage]
    percentage_string = str((percentage+1)*10) + "%"
    for method in renamed_methods:
        for i in range(len(df)):
            row = df.loc[i]
            instance = {"dataset": row["dataset"]}
            instance["percentage"] = percentage_string
            instance["method"] = method
            instance["AvgErr"] = row[method]
            df_error_plot = df_error_plot.append(instance, ignore_index=True)

######################################
from matplotlib import pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(16,10))
g = sns.boxplot(data=df_error_plot,x="percentage", y="AvgErr", hue="method", ax = ax)
ax.legend(loc='upper center', bbox_to_anchor=(0.5, 1.10),
          ncol=6, fancybox=True, shadow=True)
plt.setp(ax.get_legend().get_texts(), fontsize='25') # for legend text
plt.setp(ax.get_legend().get_title(), fontsize='0') # for legend title
ax.tick_params(axis="x", labelsize=20) # x ticks font size
ax.tick_params(axis="y", labelsize=20) # y ticks font size
plt.xlabel('Percentage', fontsize=30, labelpad=30)
plt.ylabel('Average error', fontsize=30, labelpad=30)

plt.savefig('mixed_average_errors.pdf')

# %% [markdown]
# ## 3.2 - All error plots

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np

methods_1 = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE", 
    "VBSEM", 
]

methods_2 = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE",
#     "VBSEM", 
]

renamed_methods_1 = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HI-VAE", 
    "VBSEM"
]
    
renamed_methods_2 = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HI-VAE", 
#     "VBSEM"
]

max_percentage = 6
n_runs = 5
directory = "../../missing_results/mixed/"
data_names = [
        "haberman", 
        "iris", 
        "user_knowledge",
        "vertebral", 
        "ecoli", 
        "planning_relax", 
        "thoracic_surgery",
        "vehicle", 
        "thyroid",
        "parkinsons", 
        "autos", 
        "ionosphere",
        "new_qsar_biodeg",
        "housing_prices",
        "census_india"
]

data_names_fancy = ["Haberman", "Iris", "User knowledge", "Vertebral", "Ecoli", "Planning relax", "Thoracic surgery",
                   "Vehicle", "Thyroid", "Parkinsons", "Autos", "Ionosphere", "Qsar Biodeg", "Housing prices", "Census India"]



row_count = 0 # Counts for plotting (row axis)
col_count = 0 # Counts for plotting (col axis)

from matplotlib import pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(5, 3, figsize=(20,20))

for d in range(0, len(data_names)):
    data_name=data_names[d]
    
    error_dfs = [] # One for each percentage
    
    if d < 12:
        methods = methods_1
        renamed_methods = renamed_methods_1
    else:
        methods = methods_2
        renamed_methods = renamed_methods_2
    
    for p in range(1, max_percentage):
        miss_percentage_string = "0" + str(p)
        df_error_results = pd.DataFrame(columns=methods)
        
        for i in range(1, n_runs + 1):

            error_results = {"run": i}
        
                
            for method_name in methods:
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                with open(full_path) as json_file:
                    json_data = json.load(json_file)
                    runs_data = json_data["runs"]
                    errors = []
                    learning_times = []

                    if directory == "../../missing_results/discrete/":
                        error_results[method_name] = 1.0 - runs_data["run_" + str(i)]["accuracy"]
                    elif directory == "../../missing_results/continuous/":
                        error_results[method_name] = runs_data["run_" + str(i)]["nrmse"]
                    else:
                        error_results[method_name] = runs_data["run_" + str(i)]["average_error"]

            df_error_results = df_error_results.append(error_results, ignore_index=True)

        error_dfs.append(df_error_results)
    
    # Rename columns
    for i in range(0, max_percentage-1):
        error_dfs[i] = error_dfs[i].rename(columns={"HIVAE": "HI-VAE"})
    
    ############################################################################
    # Prepare DF for plotting
    ############################################################################
    df_plot = pd.DataFrame(columns=["dataset", "method", "percentage", "AvgErr"])

    for percentage in range(0, 5):
        df = error_dfs[percentage]
        percentage_string = str((percentage+1)*10) + "%"
        for method in renamed_methods:
            for i in range(len(df)):
                row = df.loc[i]
                instance = {"run": row["run"]}
                instance["percentage"] = percentage_string
                instance["method"] = method
                instance["AvgErr"] = row[method]
                df_plot = df_plot.append(instance, ignore_index=True)
                
    ############################################################################
    # Plotting
    ############################################################################
    
#     print(str(row_count) + "," + str(col_count))
    g = sns.lineplot(data=df_plot,x="percentage", y="AvgErr", hue="method", err_style="bars", ax = axs[row_count, col_count], legend=False)
    axs[row_count, col_count].set_title(data_names_fancy[d], fontsize=18)
    axs[row_count, col_count].set_ylabel("Average error", fontsize=15, labelpad=10)
    axs[row_count, col_count].set_xlabel("Percentage", fontsize=15, labelpad=10)
    axs[row_count, col_count].tick_params(axis="x", labelsize=12) # x ticks font size
    axs[row_count, col_count].tick_params(axis="y", labelsize=12) # x ticks font size
       
    #### Update row/column index of the axis plot
    col_count = col_count + 1
    if col_count == 3:
        col_count = 0
        row_count = row_count + 1
    
    #############################################################################
    # Final adjustments to the plot

axs[0,1].legend(loc='upper center', bbox_to_anchor=(0.5, 1.50),  fancybox=True, shadow=True, ncol=5, labels=['MEAN', 'MICE', 'GLFM', 'HI-VAE', 'GLSL'])
plt.setp(axs[0,1].get_legend().get_texts(), fontsize='25') # for legend text
plt.setp(axs[0,1].get_legend().get_title(), fontsize='0') # for legend title
for line in axs[0,1].get_legend().get_lines():
    line.set_linewidth(4.0)

fig.subplots_adjust(hspace=0.5)
fig.subplots_adjust(wspace=0.3)

plt.savefig('mixed_errors.pdf')

# %% [markdown]
# ## 3.3 - Execution times

# %%
import pandas as pd
import json
import statistics as stats
from os import listdir
import numpy as np
from math import nan

methods = [
    "MEAN", 
    "MICE", 
    "GLFM", 
    "HIVAE",  
    "glsl_EMPTY"
          ]
max_percentage = 6
n_runs = 5
directories = ["../../missing_results/mixed/"]
accuracy_error_dfs = []
data_names = [
        "haberman", 
        "iris", 
        "user_knowledge",
        "vertebral", 
        "ecoli", 
        "planning_relax", 
        "thoracic_surgery",
        "vehicle", 
        "thyroid",
        "parkinsons", 
        "autos", 
        "ionosphere",
        "new_qsar_biodeg",
        "housing_prices",
        "census_india"
]

df_avg_time_results = pd.DataFrame(columns=methods)
df_stdev_time_results = pd.DataFrame(columns=methods)

for directory in directories:       
    for data_name in data_names:
        # Creamos 2 diccionarios con los valores medios y sd de cada metodo
        avg_time_results = {"dataset": data_name}
        stdev_time_results = {"dataset": data_name}       
        for method_name in methods:
            learning_times = []
        
            for i in range(1, max_percentage):
                miss_percentage_string = "0" + str(i)
                json_name = data_name + "_" + miss_percentage_string + "_results_" + method_name + ".json"
                full_path = directory + data_name + "/" + json_name
                try:
                    with open(full_path) as json_file:
                        json_data = json.load(json_file)
                        runs_data = json_data["runs"]
                        for j in range(1, n_runs + 1):  
                            learning_times.append(runs_data["run_" + str(j)]["learning_time"]/1000)
                except:
                    learning_times.append(nan)
            avg_learning_time = stats.mean(learning_times)
            avg_time_results[method_name] = avg_learning_time
            stdev_learning_time = stats.stdev(learning_times)
            stdev_time_results[method_name] = stdev_learning_time
        
        df_avg_time_results = df_avg_time_results.append(avg_time_results, ignore_index=True)
        df_stdev_time_results = df_stdev_time_results.append(stdev_time_results, ignore_index=True)
        
df_avg_time_results
# df_stdev_time_results
# Out:
#        MEAN       MICE          GLFM        HIVAE    glsl_EMPTY  \
# 0   0.00012   0.028133      8.474717    45.353637      34.94292
# 1   0.00028   0.055743      8.647240    49.409340     114.92236
# 2   0.00740   0.071361     19.573078    73.281336      86.26540
# 3   0.00024   0.076163     38.314827    74.094252     804.43860
# 4   0.00060   0.085096     31.869875    70.966427    1997.55776
# 5   0.00028   0.150431     54.414113   108.184639     888.81436
# 6   0.00656   0.165648    139.673912   171.178160    4060.88940
# 7   0.00164   0.253028    562.695525   302.297035  310741.70240
# 8   0.01584   0.569614   2722.984205   520.565361  654996.82216
# 9   0.00064   0.368995    134.346720   193.929965   47831.02568
# 10  0.00084   0.342108    151.865201   176.697035  288169.35648
# 11  0.00180   0.657622    470.756712   400.097987  105642.05120
# 12  0.00452   1.538535   3209.044414   562.454750           NaN
# 13  0.03748   5.374939  13403.679882   771.793952           NaN
# 14  0.03580  25.871706  47979.608938  1748.121393           NaN
#
#              dataset
# 0           haberman
# 1               iris
# 2     user_knowledge
# 3          vertebral
# 4              ecoli
# 5     planning_relax
# 6   thoracic_surgery
# 7            vehicle
# 8            thyroid
# 9         parkinsons
# 10             autos
# 11        ionosphere
# 12   new_qsar_biodeg
# 13    housing_prices
# 14      census_india
