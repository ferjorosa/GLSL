# %%
from scipy.io import arff
import pandas as pd

path = "../data/"
name = "wdbc"
data = arff.loadarff(path + name + ".arff")
data = pd.DataFrame(data[0])

data.drop(["class"], inplace=True, axis=1)
data
# Out:
#      RealValuedInputFeature_1  RealValuedInputFeature_2  \
# 0                       17.99                     10.38
# 1                       20.57                     17.77
# 2                       19.69                     21.25
# 3                       11.42                     20.38
# 4                       20.29                     14.34
# ..                        ...                       ...
# 564                     21.56                     22.39
# 565                     20.13                     28.25
# 566                     16.60                     28.08
# 567                     20.60                     29.33
# 568                      7.76                     24.54
#
#      RealValuedInputFeature_3  RealValuedInputFeature_4  \
# 0                      122.80                    1001.0
# 1                      132.90                    1326.0
# 2                      130.00                    1203.0
# 3                       77.58                     386.1
# 4                      135.10                    1297.0
# ..                        ...                       ...
# 564                    142.00                    1479.0
# 565                    131.20                    1261.0
# 566                    108.30                     858.1
# 567                    140.10                    1265.0
# 568                     47.92                     181.0
#
#      RealValuedInputFeature_5  RealValuedInputFeature_6  \
# 0                     0.11840                   0.27760
# 1                     0.08474                   0.07864
# 2                     0.10960                   0.15990
# 3                     0.14250                   0.28390
# 4                     0.10030                   0.13280
# ..                        ...                       ...
# 564                   0.11100                   0.11590
# 565                   0.09780                   0.10340
# 566                   0.08455                   0.10230
# 567                   0.11780                   0.27700
# 568                   0.05263                   0.04362
#
#      RealValuedInputFeature_7  RealValuedInputFeature_8  \
# 0                     0.30010                   0.14710
# 1                     0.08690                   0.07017
# 2                     0.19740                   0.12790
# 3                     0.24140                   0.10520
# 4                     0.19800                   0.10430
# ..                        ...                       ...
# 564                   0.24390                   0.13890
# 565                   0.14400                   0.09791
# 566                   0.09251                   0.05302
# 567                   0.35140                   0.15200
# 568                   0.00000                   0.00000
#
#      RealValuedInputFeature_9  RealValuedInputFeature_10  ...  \
# 0                      0.2419                    0.07871  ...
# 1                      0.1812                    0.05667  ...
# 2                      0.2069                    0.05999  ...
# 3                      0.2597                    0.09744  ...
# 4                      0.1809                    0.05883  ...
# ..                        ...                        ...  ...
# 564                    0.1726                    0.05623  ...
# 565                    0.1752                    0.05533  ...
# 566                    0.1590                    0.05648  ...
# 567                    0.2397                    0.07016  ...
# 568                    0.1587                    0.05884  ...
#
#      RealValuedInputFeature_21  RealValuedInputFeature_22  \
# 0                       25.380                      17.33
# 1                       24.990                      23.41
# 2                       23.570                      25.53
# 3                       14.910                      26.50
# 4                       22.540                      16.67
# ..                         ...                        ...
# 564                     25.450                      26.40
# 565                     23.690                      38.25
# 566                     18.980                      34.12
# 567                     25.740                      39.42
# 568                      9.456                      30.37
#
#      RealValuedInputFeature_23  RealValuedInputFeature_24  \
# 0                       184.60                     2019.0
# 1                       158.80                     1956.0
# 2                       152.50                     1709.0
# 3                        98.87                      567.7
# 4                       152.20                     1575.0
# ..                         ...                        ...
# 564                     166.10                     2027.0
# 565                     155.00                     1731.0
# 566                     126.70                     1124.0
# 567                     184.60                     1821.0
# 568                      59.16                      268.6
#
#      RealValuedInputFeature_25  RealValuedInputFeature_26  \
# 0                      0.16220                    0.66560
# 1                      0.12380                    0.18660
# 2                      0.14440                    0.42450
# 3                      0.20980                    0.86630
# 4                      0.13740                    0.20500
# ..                         ...                        ...
# 564                    0.14100                    0.21130
# 565                    0.11660                    0.19220
# 566                    0.11390                    0.30940
# 567                    0.16500                    0.86810
# 568                    0.08996                    0.06444
#
#      RealValuedInputFeature_27  RealValuedInputFeature_28  \
# 0                       0.7119                     0.2654
# 1                       0.2416                     0.1860
# 2                       0.4504                     0.2430
# 3                       0.6869                     0.2575
# 4                       0.4000                     0.1625
# ..                         ...                        ...
# 564                     0.4107                     0.2216
# 565                     0.3215                     0.1628
# 566                     0.3403                     0.1418
# 567                     0.9387                     0.2650
# 568                     0.0000                     0.0000
#
#      RealValuedInputFeature_29  RealValuedInputFeature_30
# 0                       0.4601                    0.11890
# 1                       0.2750                    0.08902
# 2                       0.3613                    0.08758
# 3                       0.6638                    0.17300
# 4                       0.2364                    0.07678
# ..                         ...                        ...
# 564                     0.2060                    0.07115
# 565                     0.2572                    0.06637
# 566                     0.2218                    0.07820
# 567                     0.4087                    0.12400
# 568                     0.2871                    0.07039
#
# [569 rows x 30 columns]

# %%
data.to_csv(name + ".csv", index=False)
