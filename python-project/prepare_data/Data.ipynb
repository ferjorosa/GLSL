# %% [markdown]
# # Objetive
#
# Load each dataset and generate a summary that includes:
# * Name
# * Number of instances
# * Number of attributes
# * Number of continuous attributes
# * Total number of attributes

# %% [markdown]
# ## DISCRETE

# %%
from os import listdir
from os.path import isfile, join, splitext
from scipy.io import arff
import pandas as pd

path = "../../data/discrete/"
data_names = [splitext(file)[0] for file in listdir(path)] # Split the file name from its extension, i.e., "alarm.arff" -> ("alarm", ".arff")

data_info = pd.DataFrame(columns=["name", "n_instances", "n_attributes"])
for name in data_names:
    data = arff.loadarff(path + name + ".arff")
    data = pd.DataFrame(data[0])
    n_nominal_attributes = sum(type == "object" for type in data.dtypes.values)
    n_numerical_attributes = len(data.dtypes.values) - n_nominal_attributes
    data_info = data_info.append({"name": name, 
                                  "n_instances": data.shape[0],
                                  "n_nominal_attributes": str(n_nominal_attributes),
                                  "n_numerical_attributes": str(n_numerical_attributes),
                                  "n_attributes": data.shape[1]}, ignore_index=True)
    
data_info.sort_values(by='n_attributes', ascending=True)
# Out:
#               name n_instances n_attributes n_nominal_attributes  \
# 6         hiv_test         428            4                    4
# 1    balance_scale         625            5                    5
# 5       hayes_roth         160            5                    5
# 3   car_evaluation        1728            7                    7
# 8          nursery       12960            9                    9
# 2    breast_cancer         277           10                   10
# 13    web_phishing        1353           10                   10
# 9      solar_flare        1389           13                   13
# 11            vote         232           17                   17
# 14             zoo         101           17                   17
# 10     spect_heart         267           23                   23
# 0            alarm        1000           37                   37
# 4          coil_42        5822           42                   42
# 7         news_100       16242          100                  100
# 12       webkb_336        1038          344                  344
#
#    n_numerical_attributes
# 6                       0
# 1                       0
# 5                       0
# 3                       0
# 8                       0
# 2                       0
# 13                      0
# 9                       0
# 11                      0
# 14                      0
# 10                      0
# 0                       0
# 4                       0
# 7                       0
# 12                      0

# %% [markdown]
# ## CONTINUOUS

# %%
from os import listdir
from os.path import isfile, join, splitext
from scipy.io import arff
import pandas as pd

path = "../../data/continuous/"
data_names = [splitext(file)[0] for file in listdir(path)] # Split the file name from its extension, i.e., "alarm.arff" -> ("alarm", ".arff")

data_info = pd.DataFrame(columns=["name", "n_instances", "n_attributes"])
for name in data_names:
    data = arff.loadarff(path + name + ".arff")
    data = pd.DataFrame(data[0])
    n_nominal_attributes = sum(type == "object" for type in data.dtypes.values)
    n_numerical_attributes = len(data.dtypes.values) - n_nominal_attributes
    data_info = data_info.append({"name": name, 
                                  "n_instances": data.shape[0],
                                  "n_nominal_attributes": str(n_nominal_attributes),
                                  "n_numerical_attributes": str(n_numerical_attributes),
                                  "n_attributes": data.shape[1]}, ignore_index=True)
    
data_info.sort_values(by='n_attributes', ascending=True)
# Out:
#                     name n_instances n_attributes n_nominal_attributes  \
# 9   real_state_valuation         414            5                    0
# 2              buddymove         249            6                    0
# 8     qsar_fish_toxicity         908            7                    0
# 4                   ilpd         579            9                    0
# 7     qsar_aqua_toxicity         545            9                    0
# 1                alcohol         125           10                    0
# 10        travel_reviews         980           10                    0
# 14    wine_quality_white        4898           12                    0
# 13                  wine         178           13                    0
# 5                   leaf         340           14                    0
# 6                    nba         441           18                    0
# 12                  wdbc         569           30                    0
# 11              waveform        5000           40                    0
# 0             100_plants        1600           64                    0
# 3              geo_music        1059           70                    0
#
#    n_numerical_attributes
# 9                       5
# 2                       6
# 8                       7
# 4                       9
# 7                       9
# 1                      10
# 10                     10
# 14                     12
# 13                     13
# 5                      14
# 6                      18
# 12                     30
# 11                     40
# 0                      64
# 3                      70

# %% [markdown]
# ## MIXED

# %%
from os import listdir
from os.path import isfile, join, splitext
from scipy.io import arff
import pandas as pd

path = "../../data/mixed/"
data_names = [splitext(file)[0] for file in listdir(path)] # Split the file name from its extension, i.e., "alarm.arff" -> ("alarm", ".arff")

data_info = pd.DataFrame(columns=["name", "n_instances", "n_attributes"])
for name in data_names:
    data = arff.loadarff(path + name + ".arff")
    data = pd.DataFrame(data[0])
    n_nominal_attributes = sum(type == "object" for type in data.dtypes.values)
    n_numerical_attributes = len(data.dtypes.values) - n_nominal_attributes
    data_info = data_info.append({"name": name, 
                                  "n_instances": data.shape[0],
                                  "n_nominal_attributes": str(n_nominal_attributes),
                                  "n_numerical_attributes": str(n_numerical_attributes),
                                  "n_attributes": data.shape[1]}, ignore_index=True)
    
data_info.sort_values(by='n_attributes', ascending=True)
# Out:
#                 name n_instances n_attributes n_nominal_attributes  \
# 3           haberman         306            4                    1
# 6               iris         150            5                    1
# 12    user_knowledge         258            6                    1
# 2              ecoli         336            7                    1
# 14         vertebral         310            7                    1
# 8     planning_relax         182           13                    1
# 10  thoracic_surgery         470           14                   11
# 13           vehicle         846           19                    1
# 11           thyroid        3103           21                   16
# 7         parkinsons         195           23                    1
# 0              autos         193           24                   10
# 5         ionosphere         351           34                    1
# 9        qsar_biodeg        1055           41                    8
# 4     housing_prices        1338           67                   33
# 1       census_india        1908          143                    1
#
#    n_numerical_attributes
# 3                       3
# 6                       4
# 12                      5
# 2                       6
# 14                      6
# 8                      12
# 10                      3
# 13                     18
# 11                      5
# 7                      22
# 0                      14
# 5                      33
# 9                      33
# 4                      34
# 1                     142

# %% [markdown]
# ## ALL

# %%
paths = ["../../data/discrete/", "../../data/continuous/", "../../data/mixed/"]

data_info = pd.DataFrame(columns=["name", "n_instances", "n_attributes"])

for path in paths:
    data_names = [splitext(file)[0] for file in listdir(path)] # Split the file name from its extension, i.e., "alarm.arff" -> ("alarm", ".arff")
    for name in data_names:
        data = arff.loadarff(path + name + ".arff")
        data = pd.DataFrame(data[0])
        n_nominal_attributes = sum(type == "object" for type in data.dtypes.values)
        n_numerical_attributes = len(data.dtypes.values) - n_nominal_attributes
        data_info = data_info.append({"name": name, 
                                      "n_instances": data.shape[0],
                                      "n_nominal_attributes": str(n_nominal_attributes),
                                      "n_numerical_attributes": str(n_numerical_attributes),
                                      "n_attributes": data.shape[1]}, ignore_index=True)

print(data_info.shape)
data_info_sorted = data_info.sort_values(by='n_attributes', ascending=True)
data_info_sorted
# Out:
# (45, 5)
#                     name n_instances n_attributes n_nominal_attributes  \
# 6               hiv_test         428            4                    4
# 33              haberman         306            4                    1
# 1          balance_scale         625            5                    5
# 36                  iris         150            5                    1
# 5             hayes_roth         160            5                    5
# 24  real_state_valuation         414            5                    0
# 42        user_knowledge         258            6                    1
# 17             buddymove         249            6                    0
# 44             vertebral         310            7                    1
# 3         car_evaluation        1728            7                    7
# 32                 ecoli         336            7                    1
# 23    qsar_fish_toxicity         908            7                    0
# 19                  ilpd         579            9                    0
# 22    qsar_aqua_toxicity         545            9                    0
# 8                nursery       12960            9                    9
# 2          breast_cancer         277           10                   10
# 16               alcohol         125           10                    0
# 13          web_phishing        1353           10                   10
# 25        travel_reviews         980           10                    0
# 29    wine_quality_white        4898           12                    0
# 38        planning_relax         182           13                    1
# 28                  wine         178           13                    0
# 9            solar_flare        1389           13                   13
# 40      thoracic_surgery         470           14                   11
# 20                  leaf         340           14                    0
# 14                   zoo         101           17                   17
# 11                  vote         232           17                   17
# 21                   nba         441           18                    0
# 43               vehicle         846           19                    1
# 41               thyroid        3103           21                   16
# 37            parkinsons         195           23                    1
# 10           spect_heart         267           23                   23
# 30                 autos         193           24                   10
# 27                  wdbc         569           30                    0
# 35            ionosphere         351           34                    1
# 0                  alarm        1000           37                   37
# 26              waveform        5000           40                    0
# 39           qsar_biodeg        1055           41                    8
# 4                coil_42        5822           42                   42
# 15            100_plants        1600           64                    0
# 34        housing_prices        1338           67                   33
# 18             geo_music        1059           70                    0
# 7               news_100       16242          100                  100
# 31          census_india        1908          143                    1
# 12             webkb_336        1038          344                  344
#
#    n_numerical_attributes
# 6                       0
# 33                      3
# 1                       0
# 36                      4
# 5                       0
# 24                      5
# 42                      5
# 17                      6
# 44                      6
# 3                       0
# 32                      6
# 23                      7
# 19                      9
# 22                      9
# 8                       0
# 2                       0
# 16                     10
# 13                      0
# 25                     10
# 29                     12
# 38                     12
# 28                     13
# 9                       0
# 40                      3
# 20                     14
# 14                      0
# 11                      0
# 21                     18
# 43                     18
# 41                      5
# 37                     22
# 10                      0
# 30                     14
# 27                     30
# 35                     33
# 0                       0
# 26                     40
# 39                     33
# 4                       0
# 15                     64
# 34                     34
# 18                     70
# 7                       0
# 31                    142
# 12                      0
